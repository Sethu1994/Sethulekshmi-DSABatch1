# %% [markdown]
# # Breakout Room 9

# %% [markdown]
# Sethulekshmi S
# Sona Roy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\useme\Downloads\hotel-tips.csv')

# %%
data
# Out:
#      Unknown  bill_id  total_bill   tip     sex smoker   day    time  size
# 0        110    10111       16.99  1.01  Female     No   Sun  Dinner     2
# 1        111    10112       10.34  1.66    Male     No   Sun  Dinner     3
# 2        112    10113       21.01  3.50    Male     No   Sun  Dinner     3
# 3        113    10114       23.68  3.31    Male     No   Sun  Dinner     2
# 4        114    10115       24.59  3.61  Female     No   Sun  Dinner     4
# ..       ...      ...         ...   ...     ...    ...   ...     ...   ...
# 239      349    10350       29.03  5.92    Male     No   Sat  Dinner     3
# 240      350    10351       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241      351    10352       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      352    10353       17.82  1.75    Male     No   Sat  Dinner     2
# 243      353    10354       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 9 columns]

# %%
data.head()
# Out:
#    Unknown  bill_id  total_bill   tip     sex smoker  day    time  size
# 0      110    10111       16.99  1.01  Female     No  Sun  Dinner     2
# 1      111    10112       10.34  1.66    Male     No  Sun  Dinner     3
# 2      112    10113       21.01  3.50    Male     No  Sun  Dinner     3
# 3      113    10114       23.68  3.31    Male     No  Sun  Dinner     2
# 4      114    10115       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.tail()
# Out:
#      Unknown  bill_id  total_bill   tip     sex smoker   day    time  size
# 239      349    10350       29.03  5.92    Male     No   Sat  Dinner     3
# 240      350    10351       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241      351    10352       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      352    10353       17.82  1.75    Male     No   Sat  Dinner     2
# 243      353    10354       18.78  3.00  Female     No  Thur  Dinner     2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unknown     244 non-null    int64
#  1   bill_id     244 non-null    int64
#  2   total_bill  244 non-null    float64
#  3   tip         244 non-null    float64
#  4   sex         244 non-null    object
#  5   smoker      244 non-null    object
#  6   day         244 non-null    object
#  7   time        244 non-null    object
#  8   size        244 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 17.3+ KB

# %%
data.describe()
# Out:
#           Unknown       bill_id  total_bill         tip        size
# count  244.000000    244.000000  244.000000  244.000000  244.000000
# mean   231.500000  10232.500000   19.785943    2.998279    2.569672
# std     70.580923     70.580923    8.902412    1.383638    0.951100
# min    110.000000  10111.000000    3.070000    1.000000    1.000000
# 25%    170.750000  10171.750000   13.347500    2.000000    2.000000
# 50%    231.500000  10232.500000   17.795000    2.900000    2.000000
# 75%    292.250000  10293.250000   24.127500    3.562500    3.000000
# max    353.000000  10354.000000   50.810000   10.000000    6.000000

# %%
data.shape
# Out:
# (244, 9)

# %%
data=data.rename(columns={'Unknown':'Sl_No'})

# %%
data.head()
# Out:
#    Sl_No  bill_id  total_bill   tip     sex smoker  day    time  size
# 0    110    10111       16.99  1.01  Female     No  Sun  Dinner     2
# 1    111    10112       10.34  1.66    Male     No  Sun  Dinner     3
# 2    112    10113       21.01  3.50    Male     No  Sun  Dinner     3
# 3    113    10114       23.68  3.31    Male     No  Sun  Dinner     2
# 4    114    10115       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
data['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
plt.bar(data['day'],data['total_bill'],color='g')
plt.title('Distribution of Total Bill')
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.show()

# %% [markdown]
# Inference : The total bill amount was high on Saturday compared to other days.

# %%
data['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
plt.bar(data['sex'],data['total_bill'],color='g')
plt.title('Distribution of Total Bill/sex')
plt.xlabel('Sex')
plt.ylabel('Total Bill')
plt.show()

# %% [markdown]
# Inference: The maximum bill was paid by the male category.

# %%
plt.bar(data['day'],data['tip'])
plt.title('Distribution of Tip')
plt.xlabel('Day')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# Inference: The total tip amount was high on Saturday.

# %%
plt.bar(data['sex'],data['tip'])
plt.title('Distribution of tip/sex')
plt.xlabel('Sex')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# Inference: The maximum tip was paid by the male category.

# %%
plt.boxplot(data['total_bill'])
plt.show()

# %%
data['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
plt.bar(data['time'],data['total_bill'])
plt.title('Distribution of Total bill/Time')
plt.xlabel('Time')
plt.ylabel('Total Bill')
plt.show()

# %% [markdown]
# Inference: The maximum bill was paid for dinner, which means people usually come for dinner rather than lunch.

# %%
plt.boxplot(data['tip'])
plt.show()

# %%
plt.hist(data['tip'])
plt.title('Distribution of tip')
plt.show()

# %%
plt.hist(data['total_bill'])
plt.title('Distribution of Total Bill')
plt.show()

# %%
sns.countplot(x=data.smoker)
plt.show()

# %% [markdown]
# Inference: The customers of this hotel include smokers and non-smokers. People who smoke are in high numbers.

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='size',data=data)
plt.show()

# %% [markdown]
# Inference : The people who come here are mostly in groups of 2 rather than groups of 3, 4, or 6.

# %%
plt.scatter(data['total_bill'],data['tip'])
plt.show()

# %% [markdown]
# The bill increases,tip also increases.

# %%
sns.pairplot(data)

# %%
data1= data[['total_bill','tip','sex','day','time']]
sns.heatmap(data1.corr())
# Out:
# C:\Users\useme\AppData\Local\Temp\ipykernel_5636\2896077901.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data1.corr())
# <Axes: >
